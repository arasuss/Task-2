# %% [markdown]
# <a href="https://colab.research.google.com/github/arasuss/Task-2/blob/main/KTask_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/Video Games Sales - Video Games Sales.csv.csv',index_col='index')
df.head()
# Out:
#        Rank         Game Title Platform    Year     Genre Publisher  \
# index
# 0         1         Wii Sports      Wii  2006.0    Sports  Nintendo
# 1         2  Super Mario Bros.      NES  1985.0  Platform  Nintendo
# 2         3     Mario Kart Wii      Wii  2008.0    Racing  Nintendo
# 3         4  Wii Sports Resort      Wii  2009.0    Sports  Nintendo
# 4         5             Tetris       GB  1989.0    Puzzle  Nintendo
#
#        North America  Europe  Japan  Rest of World  Global  Review
# index
# 0              40.43   28.39   3.77           8.54   81.12   76.28
# 1              29.08    3.58   6.81           0.77   40.24   91.00
# 2              14.50   12.22   3.63           3.21   33.55   82.07
# 3              14.82   10.51   3.18           3.01   31.52   82.65
# 4              23.20    2.26   4.22           0.58   30.26   88.00

# %%
for i in df:
  print(f'{i}: {df[i].unique()}')
  print("---------------------------")
# Out:
# Rank: [   1    2    3 ... 1905 1906 1907]
# ---------------------------
# Game Title: ['Wii Sports' 'Super Mario Bros.' 'Mario Kart Wii' ...
#  'Lizzie McGuire 2: Lizzie Diaries' 'Xenoblade Chronicles'
#  'FIFA Soccer World Championship']
# ---------------------------
# Platform: ['Wii' 'NES' 'GB' 'DS' 'PS2' 'SNES' 'X360' 'GBA' 'PS3' 'N64' 'PC' 'PS'
#  'XB' '3DS' 'PSP' 'GC' 'GEN' 'DC' 'SAT' 'WiiU' 'SCD' 'PSV']
# ---------------------------
# Year: [2006. 1985. 2008. 2009. 1989. 1984. 2005. 1999. 2007. 2004. 1990. 2010.
#  1988. 2002. 2001. 2011. 1998. 1996. 2012. 2000. 1992. 1997. 1993. 1994.
#  2003. 1986.   nan 1995. 1991. 1987. 1983.]
# ---------------------------
# Genre: ['Sports' 'Platform' 'Racing' 'Puzzle' 'Misc' 'Shooter' 'Simulation'
#  'Role-Playing' 'Action' 'Fighting' 'Adventure' 'Strategy']
# ---------------------------
# Publisher: ['Nintendo' 'Take-Two Interactive' 'Microsoft Game Studios'
#  'Sony Computer Entertainment' 'Activision' 'Electronic Arts' 'Ubisoft'
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1907 entries, 0 to 1906
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           1907 non-null   int64
#  1   Game Title     1907 non-null   object
#  2   Platform       1907 non-null   object
#  3   Year           1878 non-null   float64
#  4   Genre          1907 non-null   object
#  5   Publisher      1905 non-null   object
#  6   North America  1907 non-null   float64
#  7   Europe         1907 non-null   float64
#  8   Japan          1907 non-null   float64
#  9   Rest of World  1907 non-null   float64
#  10  Global         1907 non-null   float64
#  11  Review         1907 non-null   float64
# dtypes: float64(7), int64(1), object(4)
# memory usage: 193.7+ KB

# %%
numerical = df.select_dtypes(exclude='object')
categorical = df.select_dtypes(include='object')

# %%
o1=df['Platform'].value_counts(ascending=False).index

# %%
#plt.figure(figsize=(6,8))
sns.countplot(y='Platform',data=df,order=o1)

# %%
plt.figure(figsize=(6,8))
sns.countplot(y='Year',data=df)

# %%
df8 = df.loc[df['Year']==2008]

# %%
sns.countplot(x='Platform',data=df8)

# %%
o2 = df8['Genre'].value_counts(ascending=False).index

# %%
df['Genre'].value_counts(ascending=False)
# Out:
# Sports          308
# Action          275
# Shooter         206
# Platform        188
# Racing          186
# Role-Playing    173
# Misc            159
# Fighting        126
# Adventure       110
# Simulation       92
# Puzzle           44
# Strategy         40
# Name: Genre, dtype: int64

# %%
o2
# Out:
# Index(['Sports', 'Action', 'Shooter', 'Platform', 'Racing', 'Role-Playing',
#        'Misc', 'Fighting', 'Adventure', 'Simulation', 'Puzzle', 'Strategy'],
#       dtype='object')

# %%
sns.countplot(y='Genre',data=df8,order=o2)

# %%
pub = df['Publisher'].value_counts(ascending=False)

# %%
pub=pub[:10]

# %%
sns.barplot(y=pub.index,x=pub.values)

# %%
df.loc[df['Genre']=='Platform']
# Out:
#        Rank                                  Game Title Platform    Year  \
# index
# 1         2                           Super Mario Bros.      NES  1985.0
# 5         6                       New Super Mario Bros.       DS  2006.0
# 8         9                   New Super Mario Bros. Wii      Wii  2009.0
# 15       16                           Super Mario World     SNES  1990.0
# 18       19                            Super Mario Land       GB  1989.0
# ...     ...                                         ...      ...     ...
# 1802   1803  Mega Man 8 Anniversary Collector's Edition       PS  1996.0
# 1817   1818                                         Gex       PS  1995.0
# 1843   1844                          Kirby: Mass Attack       DS  2011.0
# 1866   1867                                 Ratatouille      PS2  2007.0
# 1882   1883                             Sonic Unleashed     X360  2008.0
#
#           Genre         Publisher  North America  Europe  Japan  \
# index
# ...

# %%
df['Review'].value_counts(ascending=False)
# Out:
# 84.00    63
# 85.00    61
# 82.00    60
# 81.00    60
# 86.00    56
#          ..
# 80.13     1
# 73.04     1
# 89.60     1
# 83.83     1
# 91.74     1
# Name: Review, Length: 734, dtype: int64

# %%
t10g=df.sort_values(by='Review',ascending=False).iloc[:10,]

# %%
t10g
# Out:
#        Rank                            Game Title Platform    Year  \
# index
# 73       74  The Legend of Zelda: Ocarina of Time      N64  1998.0
# 821     822                        The Orange Box     X360  2007.0
# 411     412                         Metroid Prime       GC  2002.0
# 78       79                              Tekken 3       PS  1998.0
# 461     462                              BioShock     X360  2007.0
# 264     265                 Batman: Arkham Asylum      PS3  2009.0
# 838     839                       Resident Evil 4       GC  2005.0
# 278     279                       Resident Evil 4      PS2  2005.0
# 378     379                         Mass Effect 2     X360  2010.0
# 92       93                  Halo: Combat Evolved       XB  2001.0
#
#               Genre                    Publisher  North America  Europe  \
# index
# 73        Adventure                     Nintendo           4.10    1.89
# ...

# %%
sns.barplot(x='Review',y='Game Title',data=t10g)

# %%
g10g=df.sort_values(by='Global',ascending=False).iloc[:10,]

# %%
g10g
# Out:
#        Rank                 Game Title Platform    Year       Genre Publisher  \
# index
# 0         1                 Wii Sports      Wii  2006.0      Sports  Nintendo
# 1         2          Super Mario Bros.      NES  1985.0    Platform  Nintendo
# 2         3             Mario Kart Wii      Wii  2008.0      Racing  Nintendo
# 3         4          Wii Sports Resort      Wii  2009.0      Sports  Nintendo
# 4         5                     Tetris       GB  1989.0      Puzzle  Nintendo
# 5         6      New Super Mario Bros.       DS  2006.0    Platform  Nintendo
# 6         7                   Wii Play      Wii  2006.0        Misc  Nintendo
# 7         8                  Duck Hunt      NES  1984.0     Shooter  Nintendo
# 8         9  New Super Mario Bros. Wii      Wii  2009.0    Platform  Nintendo
# 9        10                 Nintendogs       DS  2005.0  Simulation  Nintendo
#
#        North America  Europe  Japan  Rest of World  Global  Review
# index
# ...

# %%
sns.barplot(x='Review',y='Game Title',data=g10g)

# %%
e10g=df.sort_values(by='Europe',ascending=False).iloc[:10,]

# %%
sns.barplot(x='Review',y='Game Title',data=e10g)

# %%
j10g=df.sort_values(by='Japan',ascending=False).iloc[:10,]

# %%
j10g
# Out:
#        Rank                                      Game Title Platform    Year  \
# index
# 10       11                   Pokémon Gold / Silver Version       GB  1999.0
# 1         2                               Super Mario Bros.      NES  1985.0
# 5         6                           New Super Mario Bros.       DS  2006.0
# 19       20                 Pokémon Diamond / Pearl Version       DS  2006.0
# 27       28                   Pokémon Black / White Version       DS  2010.0
# 22       23                 Pokémon Ruby / Sapphire Version      GBA  2002.0
# 35       36                     Animal Crossing: Wild World       DS  2005.0
# 23       24     Brain Age 2: More Training in Minutes a Day       DS  2005.0
# 8         9                       New Super Mario Bros. Wii      Wii  2009.0
# 119     120  Dragon Quest IX: Sentinels of the Starry Skies       DS  2009.0
#
#               Genre Publisher  North America  Europe  Japan  Rest of World  \
# index
# ...

# %%
sns.barplot(x='Review',y='Game Title',data=j10g)

# %%
n10g=df.sort_values(by='North America',ascending=False).iloc[:10,]

# %%
sns.barplot(x='Review',y='Game Title',data=n10g)
